# %%
# Exercises
# Using the repo setup directions, setup a new local and remote repository
    # named numpy-pandas-visualization-exercises. The local version of your
    # repo should live inside of ~/codeup-data-science. This repo should be
    # named numpy-pandas-visualization-exercises

# Do your work for this exercise in a jupyter notebook named 
    # matplotlib_exercises.
import matplotlib.pyplot as plt
import math
import numpy as np



print(plt)
# Out:
# <module 'matplotlib.pyplot' from '/opt/homebrew/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
# 1. Use matplotlib to plot the following equation:

    # y = x^2 − x + 2
    # You'll need to write the code that generates the x and y points.

    # Add an anotation for the point 0, 0, the origin.
print('\nQuestion 1')
x = np.array(range(-10,11))

x = range(-49, 50)
y = [n ** 2 - n + 2 for n in x] # This is the same as y = x^2 − x + 2

plt.plot(x, y, c='blue')
plt.title('A Quadratic Distribution, $y = x^2 − x + 2$')
plt.xlabel('$x$')
plt.ylabel('$x^2$')
plt.annotate('Intersection', xy=(0,0), xytext=(0,300), arrowprops={'facecolor': 'blue'})

plt.show()
# Out:
# Question 1

# %%
# 2. Create and label 4 separate charts for the following equations
    # (choose a range for x that makes sense):

    # y = √ x - good 
    # y = x^3
    # y = 2^x
    # y = 1 / (x + 1)

    # You can use functions from the math module to help implement
    #  some of the equations above.
print('\nQuestion 2')

# The first plot plot
n1 = np.array(range(10))
y1 = [n**.5 for n in n1] # This is the same as y = √ x
fig1 = plt.figure(figsize=(2,2))
plt.plot(x, y)
plt.title('Graph 1')
plt.xlabel('$x$')
plt.ylabel('$y = √ x$')


# # The second plot
n2 = np.array(range(-10,10))
y2 = [n2 ** 3 for n in n2] # This is the same as y = x^3
fig2 = plt.figure(figsize=(2,2))
plt.plot(x, y)
plt.title('Graph 2')
plt.xlabel('$x$')
plt.ylabel('$y = x^3$')

# # The third plot
n3 = np.array(range(10))
y3 = [2 ** n3 for n in n3] # This is the same as y = 2^x
fig3 = plt.figure(figsize=(2,2))
plt.plot(x, y)
plt.title('Graph 3')
plt.xlabel('$x$')
plt.ylabel('$y = 2^n$')

# # The fourh plot
n4 = np.linspace(-10,10,100)
y4 = [(1) / (n4 + 1) for n in n4] # This is the same as y = 1 / (x + 1)
fig4 = plt.figure(figsize=(2,2))
plt.plot(x, y)
plt.title('Graph 4')
plt.xlabel('$x$')
plt.ylabel('$y = \\frac{1}{(x + 1)}$')


plt.show()
# Out:
# Question 2

# %%
# 3. Combine the figures you created in the last step into one large
    # figure with 4 subplots.
print('\nQuestion 3')

plt.figure(figsize=(14, 8))
plt.suptitle('Subplot')
n = np.array(range(1,20))

# The first subplot
plt.subplot(221)
y = [n**.5 for n in n] # This is the same as y = √ x
plt.plot(x, y)
plt.xlabel('$x$')
plt.ylabel('$y = √ x$')


# # The second subplot
plt.subplot(222)
y = [n ** 3 for n in n] # This is the same as y = x^3
plt.plot(x, y)
plt.xlabel('$x$')
plt.ylabel('$y = x^3$')

# # The third subplot
plt.subplot(223)
y = [2 ** n for n in n] # This is the same as y = 2^x
plt.plot(x, y)
plt.xlabel('$x$')
plt.ylabel('$y = 2^n$')

# # The fourh subplot
plt.subplot(224)
y = [(1) / (n + 1) for n in n] # This is the same as y = 1 / (x + 1)
plt.plot(x, y)
plt.xlabel('$x$')
plt.ylabel('$y = \\frac{1}{(x + 1)}$')


plt.show()
# Out:
# Question 3

# %%
# 4. Combine the figures you created in the last step into one figure
    # where each of the 4 equations has a different color for the points.
    # Be sure to include a legend and an appropriate title for the figure.
print('\nQuestion 4')

plt.figure(figsize=(14, 8))
plt.suptitle('Subplot')
n = np.array(range(1,20))

# The first subplot
y1 = [n**.5 for n in n] # This is the same as y = √ x


y2 = [n ** 3 for n in n] # This is the same as y = x^3


y3 = [2 ** n for n in n] # This is the same as y = 2^x


y4 = [(1) / (n + 1) for n in n] # This is the same as y = 1 / (x + 1)

 
plt.figure(figsize=(12, 10))
plt.plot(n, y1, color='red', label='$y = √ x$')
plt.plot(n, y2, color='darkgreen', label='$y = x^3$')
plt.plot(n, y3, color='blue', label='$y = 2^x$')
plt.plot(n, y4, color='purple', label='$y = \\frac{1}{(x + 1)}$')

plt.xlabel('$x$')
plt.ylabel('$y$')
plt.xlim(0,5)
plt.ylim(0,120)

plt.legend()
plt.title('Four Plots')
plt.show()
# Out:
# Question 4

# %%
# 5. Make a new Jupyter notebook named big_o_notation.ipynb

    # Title your chart "Big O Notation"
    # Label your x axis "Elements"
    # Label your y axis "Operations"
    # Label your curves or make a legend for the curves
    # Use LaTex notation where possible
    # Curves to graph

    # y = 0n + 1  and label the curve "O(1)"            c/w
    # y = log (n)  and label the curve "O(log n)"       c/w
    # y = n  and label the curve "O(n)"                 c/w
    # y = n ∗ log (n) and label it "O(n log n)"         c/w
    # y = n^2 and label it "O(n^2)"
    # y = 2^n  and label it "O(2^n)"
    # y = n^!  and label it "O(n!)"
    # y = n^n  and label it "O(n^n)"

print('\nQuestion 5')
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.special import factorial


n = np.arange(1,20)

# Calculate the y-axis values for the function y = 0n + 1
y1 = 0 * n + 1

# Compute y = log(n)
y2 = np.log(n)

# Compute y = n
y3 = n

# Compute y = n * log(n)
y4 = n * np.log(n)

# Compute y = n^2
y5 = n**2

# Compute y = 2^n
y6 = 2**dd

# Compute y = n!
y7 = factorial(n)

# Compute y = n^n
y8 = n**n

plt.figure(figsize=(12, 10))
plt.plot(n, y1, label='O(1)')
plt.plot(n, y2, label='O(log n)')
plt.plot(n, y3, label='O(n)')
plt.plot(n, y4, label='O(n log n)')
plt.plot(n, y5, label='O(n^2)')
plt.plot(n, y6, label='O(2^n)')
plt.plot(n, y7, label='O(n!)')
plt.plot(n, y8, label='O(n^n)')


plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.xlim(1,24)
plt.ylim(0,20)

plt.legend()
plt.show()
# Out:
# Question 5

# %%
# 5. Make a new Jupyter notebook named big_o_notation.ipynb

    # Title your chart "Big O Notation"
    # Label your x axis "Elements"
    # Label your y axis "Operations"
    # Label your curves or make a legend for the curves
    # Use LaTex notation where possible
    # Curves to graph

    # y = 0n + 1  and label the curve "O(1)"            c/w
    # y = log (n)  and label the curve "O(log n)"       c/w
    # y = n  and label the curve "O(n)"                 c/w
    # y = n ∗ log (n) and label it "O(n log n)"         c/w
    # y = n^2 and label it "O(n^2)"
    # y = 2^n  and label it "O(2^n)"
    # y = n^!  and label it "O(n!)"
    # y = n^n  and label it "O(n^n)"

print('\nQuestion 5')
import matplotlib.pyplot as plt
import numpy as np
import math
from scipy.special import factorial


n = np.arange(1,20)

# Calculate the y-axis values for the function y = 0n + 1
y1 = 0 * n + 1

# Compute y = log(n)
y2 = np.log(n)

# Compute y = n
y3 = n

# Compute y = n * log(n)
y4 = n * np.log(n)

# Compute y = n^2
y5 = n**2

# Compute y = 2^n
y6 = 2**n

# Compute y = n!
y7 = factorial(n)

# Compute y = n^n
y8 = n**n

# Plot the functions
plt.figure(figsize=(10,8))
plt.plot(n, y1, label='O(1)')
plt.plot(n, y2, label='O(log n)')
plt.plot(n, y3, label='O(n)')
plt.plot(n, y4, label='O(n log n)')
plt.plot(n, y5, label='O(n^2)')
plt.plot(n, y6, label='O(2^n)')
plt.plot(n, y7, label='O(n!)')
plt.plot(n, y8, label='O(n^n)')

# Add title and axis labels
plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')

# Add limits to the graph
plt.xlim(1,24)
plt.ylim(0,20)

# Add legend and show plot
plt.legend()
plt.show()
# Out:
# Question 5
